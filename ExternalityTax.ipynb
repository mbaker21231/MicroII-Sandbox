# %% [markdown]
# <a href="https://colab.research.google.com/github/mbaker21231/MicroII-Sandbox/blob/main/ExternalityTax.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A simple industry externality problem
#
# Let's suppose that we have a quadratic cost function with fixed costs of entry $F$, and variable costs of $cx^2/2$. Firms also cause an external cost of $ex^2/2$.
#
# Suppose market demand is given by $p = K - x$.
# The question:
#
# **How should we structure a pigouvian tax?**
#
# Suppose that the tax is $t$. Here we go:

# %%
K, e, c, F, x, t = symbols('K e c F x t')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3078a2ba0c74> in <cell line: 0>()
# ----> 1 K, e, c, F, x, t = symbols('K e c F x t')
#
# NameError: name 'symbols' is not defined
